# %% [markdown]
# # 05 — Visualisations
# This notebook produces all final publication-quality charts for the project writeup.
# Charts include: reaction heatmap, cumulative abnormal return plots by event category,
# annotated event time series, and forward-looking Taiwan Strait scenario chart.
# Last updated: March 2026
