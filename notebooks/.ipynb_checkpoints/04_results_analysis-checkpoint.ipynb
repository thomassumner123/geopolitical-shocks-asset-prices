# %% [markdown]
# # 04 — Results and Analysis
# This notebook applies the event study methodology across all asset classes and event categories.
# Produces results tables showing average market reactions by asset class and event type.
# Includes deeper analysis: asymmetry, persistence, anticipation effects, and statistical significance.
# Last updated: March 2026
